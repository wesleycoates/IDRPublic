# %% [markdown]
# # Data Exploration and Model Building
#
# This notebook guides you through the process of exploring your data and building a predictive model.

# %% [markdown]
# ## 1. Setup and Data Loading
#
# First, let's import the necessary libraries and load our data.

# %%
import os

# Check the exact path being used
expected_path = os.path.abspath(os.path.join('..', 'src', 'modeling.py'))
print(f"Looking for modeling.py at: {expected_path}")
print(f"File exists: {os.path.exists(expected_path)}")

# Read the first few lines to confirm it's the correct file
if os.path.exists(expected_path):
    with open(expected_path, 'r') as f:
        content = f.read(500)  # Read first 500 characters
        print("First few lines of the file:")
        print(content)
# Out:
# Looking for modeling.py at: /workspaces/IDRPublic/src/modeling.py
# File exists: True
# First few lines of the file:
# import pandas as pd
# import numpy as np
# from typing import Optional, List, Dict, Any, Tuple
# import pickle
# from pathlib import Path
#
# from sklearn.base import BaseEstimator, TransformerMixin
# from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
# from sklearn.model_selection import cross_val_score, GridSearchCV
# from sklearn.metrics import (
#     me

# %%
import importlib.util
import sys

# Load the module directly from the file path
expected_path = '/workspaces/IDRPublic/src/modeling.py'
spec = importlib.util.spec_from_file_location("modeling_direct", expected_path)
modeling_direct = importlib.util.module_from_spec(spec)
sys.modules["modeling_direct"] = modeling_direct
spec.loader.exec_module(modeling_direct)

# Check if the function exists in the loaded module
print("Function exists in direct import:", hasattr(modeling_direct, "get_numeric_and_categorical_columns"))

# Try to access the function
if hasattr(modeling_direct, "get_numeric_and_categorical_columns"):
    print("Function signature:", modeling_direct.get_numeric_and_categorical_columns.__annotations__)
# Out:
# Function exists in direct import: True
# Function signature: {'df': <class 'pandas.core.frame.DataFrame'>, 'return': typing.Tuple[typing.List[str], typing.List[str]]}

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set plotting style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 8)

# Import custom modules (adjust the path if needed)
import sys
print("Current sys.path:", sys.path)  # Print current system path
sys.path.append('../src')
print("Updated sys.path:", sys.path)  # Check if path was updated correctly

# Try importing each module separately and print confirmation
try:
    from data_loader import load_excel_data, clean_data, split_data
    print("✓ Successfully imported data_loader module")
    # Optionally print function signatures to verify they're the ones you expect
    print(f"   - load_excel_data: {load_excel_data.__doc__}")
except ImportError as e:
    print("✗ Failed to import data_loader:", e)

try:
    from visualization import plot_numeric_distribution, plot_correlation_matrix, plot_feature_importance
    print("✓ Successfully imported visualization module")
except ImportError as e:
    print("✗ Failed to import visualization:", e)

try:
    from modeling import (get_numeric_and_categorical_columns, create_preprocessing_pipeline,
                        evaluate_regression_models, evaluate_classification_models)
    print("✓ Successfully imported modeling module")
except ImportError as e:
    print("✗ Failed to import modeling:", e)

# Test if one function from each module works with minimal inputs
print("\nTesting minimal function calls:")
try:
    # Choose simple functions that won't require complex inputs
    print("Testing get_numeric_and_categorical_columns...")
    # Create a simple test dataframe
    test_df = pd.DataFrame({
        'numeric_col': [1, 2, 3],
        'categorical_col': ['A', 'B', 'C']
    })
    num_cols, cat_cols = get_numeric_and_categorical_columns(test_df)
    print(f"   - Numeric columns: {num_cols}")
    print(f"   - Categorical columns: {cat_cols}")
except Exception as e:
    print("Function test failed:", e)
# Out:
# Current sys.path: ['/usr/local/python/3.12.1/lib/python312.zip', '/usr/local/python/3.12.1/lib/python3.12', '/usr/local/python/3.12.1/lib/python3.12/lib-dynload', '', '/home/codespace/.local/lib/python3.12/site-packages', '/usr/local/python/3.12.1/lib/python3.12/site-packages']
# Updated sys.path: ['/usr/local/python/3.12.1/lib/python312.zip', '/usr/local/python/3.12.1/lib/python3.12', '/usr/local/python/3.12.1/lib/python3.12/lib-dynload', '', '/home/codespace/.local/lib/python3.12/site-packages', '/usr/local/python/3.12.1/lib/python3.12/site-packages', '../src']
# ✓ Successfully imported data_loader module
#    - load_excel_data:
#     Load data from an Excel file into a pandas DataFrame.
#
#     Parameters:
#     -----------
#     file_path : str
#         Path to the Excel file
#     sheet_name : str, optional
#         Name of the sheet to load. If None, the first sheet is loaded.
#
#     Returns:
#     --------
#     pd.DataFrame
#         The loaded data
#
# ✓ Successfully imported visualization module
# ✓ Successfully imported modeling module
#
# Testing minimal function calls:
# Testing get_numeric_and_categorical_columns...
#    - Numeric columns: ['numeric_col']
#    - Categorical columns: ['categorical_col']

# %%
# Load Excel file
file_path = "../data/raw/2023-q1-federal-idr-puf.xlsx"


# Reading in the second sheet
sheet_name = 'OON Emergency and Non-Emergency'
df = pd.read_excel(file_path, sheet_name=sheet_name)

# Display the first few rows to confirm it worked
print(f"Successfully loaded sheet: {sheet_name}")
print(f"Shape of dataframe: {df.shape}")
print("\nFirst 5 rows:")
df.head()
# Out:
# Successfully loaded sheet: OON Emergency and Non-Emergency
# Shape of dataframe: (65271, 30)
#
# First 5 rows:
#   Dispute Number    DLI Number              Payment Determination Outcome  \
# 0    DISP-135724  DLI - 582653                    In Favor of Plan/Issuer
# 1    DISP-135637  DLI - 582530                    In Favor of Plan/Issuer
# 2    DISP-135495  DLI - 582345  In Favor of Provider/Facility/AA Provider
# 3    DISP-135654  DLI - 582547  In Favor of Provider/Facility/AA Provider
# 4    DISP-135828  DLI - 582852  In Favor of Provider/Facility/AA Provider
#
#   Default Decision Type of Dispute              Provider/Facility Group Name  \
# 0               No          Single  LONGHORN EMERGENCY MEDICAL ASSOCIATES PA
# 1               No          Single                                        NR
# 2               No          Single            WOODLANDS EMERGENCY PHYSICIANS
# 3               No          Single                  APP OF TENNESSEE ED PLLC
# 4               No         Batched      Remote Neuromonitoring Physicians PC
#
#                  Provider/Facility Name Provider Email Domain  \
# 0                BLUDWORTH MD,WHITNEY G        teamhealth.com
# 1          ROXBOROUGH MEMORIAL HOSPITAL   primehealthcare.com
# 2        WOODLANDS EMERGENCY PHYSICIANS             r1rcm.com
# 3              APP OF TENNESSEE ED PLLC             r1rcm.com
# 4  Remote Neuromonitoring Physicians PC     specialtycare.net
#
#   Provider/Facility NPI Number Practice/Facility Size  ...  \
# 0                   1649669672      101-500 Employees  ...
# 1                           NR     Over 500 Employees  ...
# 2                   1467989871       51-100 Employees  ...
# 3                   1003230236      101-500 Employees  ...
# 4                   1124253075     Over 500 Employees  ...
#
#   Location of Service Practice/Facility Specialty or Type  \
# 0                  TX                  EMERGENCY MEDICINE
# 1                  PA                 ACUTE CARE HOSPITAL
# 2                  TX                  Emergency Provider
# 3                  TN                   EmergencyMedicine
# 4                  PA      Intraoperative Neuromonitoring
#
#   Provider/Facility Offer as Percent of QPA  \
# 0                                      1.64
# 1                                      5.13
# 2                                      3.19
# 3                                      2.47
# 4                                     11.04
#
#    Health Plan/Issuer Offer as Percent of QPA  \
# 0                                           1
# 1                                         0.7
# 2                                        1.15
# 3                                        1.15
# 4                                           0
#
#       Offer Selected from Provider or Issuer  \
# 0                    In Favor of Plan/Issuer
# 1                    In Favor of Plan/Issuer
# 2  In Favor of Provider/Facility/AA Provider
# 3  In Favor of Provider/Facility/AA Provider
# 4  In Favor of Provider/Facility/AA Provider
#
#   Prevailing Party Offer as Percent of QPA QPA as Percent of Median QPA  \
# 0                                        1                            1
# 1                                      0.7                            1
# 2                                     3.19                         0.27
# 3                                     2.47                         0.96
# 4                                    11.04                         0.95
#
#   Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount  \
# 0                                               0.99
# 1                                                  1
# 2                                               0.83
# 3                                               0.71
# 4                                                  1
#
#    Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount  \
# 0                                                  1
# 1                                                  1
# 2                                               0.92
# 3                                               1.15
# 4                                                  *
#
#   Prevailing Offer as Percent of Median Prevailing Offer Amount
# 0                                                  1
# 1                                                  1
# 2                                               0.88
# 3                                               0.71
# 4                                                  1
#
# [5 rows x 30 columns]

# %%
# Loading the other sheet from the Excel file
QPA_sheet = 'QPA and Offers'
df_QPA = pd.read_excel('../data/raw/2023-q1-federal-idr-puf.xlsx', sheet_name=QPA_sheet)

# Display basic info about this sheet
print(f"Successfully loaded sheet: {QPA_sheet}")
print(f"Shape of dataframe: {df_QPA.shape}")
print("\nFirst 5 rows of QPA and Offers data:")
df_QPA.head()
# Out:
# Successfully loaded sheet: QPA and Offers
# Shape of dataframe: (68007, 9)
#
# First 5 rows of QPA and Offers data:
#   Service Code  Place of Service Code Geographical Region QPA  \
# 0        A0436                   42.0        Aberdeen, WA   ^
# 1        A0431                   42.0        Aberdeen, WA   ^
# 2        A0431                   42.0        Aberdeen, WA   ^
# 3        A0431                   42.0        Aberdeen, WA   ^
# 4        A0431                   42.0        Aberdeen, WA   ^
#
#   Provider/Facility Offer Health Plan/Issuer Offer  \
# 0                       ^                        ^
# 1                       ^                        ^
# 2                       ^                        ^
# 3                       ^                        ^
# 4                       ^                        ^
#
#       Offer Selected from Provider or Issuer Prevailing Offer Default Decision
# 0  In Favor of Provider/Facility/AA Provider                ^               No
# 1  In Favor of Provider/Facility/AA Provider                ^               No
# 2  In Favor of Provider/Facility/AA Provider                ^               No
# 3  In Favor of Provider/Facility/AA Provider                ^               No
# 4  In Favor of Provider/Facility/AA Provider                ^               No

# %% [markdown]
# ## 2. Data Cleaning and Preprocessing
#
# Let's clean the data and perform some basic preprocessing.

# %%
# Basic data exploration
print("Column names in main dataframe:")
for col in df.columns:
    print(f"- {col}")

# Check for missing values
print("\nMissing values per column:")
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percent
})
missing_df[missing_df['Missing Values'] > 0].sort_values('Missing Values', ascending=False)
# Out:
# Column names in main dataframe:
# - Dispute Number
# - DLI Number
# - Payment Determination Outcome
# - Default Decision
# - Type of Dispute
# - Provider/Facility Group Name
# - Provider/Facility Name
# - Provider Email Domain
# - Provider/Facility NPI Number
# - Practice/Facility Size
# - Health Plan/Issuer Name
# - Health Plan/Issuer Email Domain
# - Health Plan Type
# - Length of Time to Make Determination
# - IDRE Compensation
# - Dispute Line Item Type
# - Type of Service Code
# - Service Code
# - Place of Service Code
# - Item or Service Description
# - Location of Service
# - Practice/Facility Specialty or Type
# - Provider/Facility Offer as Percent of QPA
# - Health Plan/Issuer Offer as Percent of QPA
# - Offer Selected from Provider or Issuer
# - Prevailing Party Offer as Percent of QPA
# - QPA as Percent of Median QPA
# - Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount
# - Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount
# - Prevailing Offer as Percent of Median Prevailing Offer Amount
#
# Missing values per column:
#                                             Missing Values  Percentage
# Health Plan/Issuer Offer as Percent of QPA           11747   17.997273
# Provider/Facility Offer as Percent of QPA             6985   10.701537
# Place of Service Code                                  594    0.910052
# Location of Service                                    594    0.910052
# Prevailing Party Offer as Percent of QPA               168    0.257388
# Item or Service Description                            107    0.163932
# Type of Service Code                                   107    0.163932
# Default Decision                                        17    0.026045
# Service Code                                             2    0.003064

# %%
# Clean the data
clean_df = clean_data(df)

# Display information about the cleaned data
print("Data information:")
clean_df.info()

# Display summary statistics
print("\nSummary statistics:")
display(clean_df.describe())

# Check for missing values
print("\nMissing values per column:")
display(clean_df.isna().sum())

# Identify numeric and categorical columns
numeric_cols, categorical_cols = get_numeric_and_categorical_columns(clean_df)
print(f"\nNumeric columns: {numeric_cols}")
print(f"Categorical columns: {categorical_cols}")

# Let's examine a sample of categorical columns if any exist
if categorical_cols:
    for col in categorical_cols[:3]:  # Show first 3 at most
        print(f"\nUnique values in {col}:")
        display(clean_df[col].value_counts())
# Out:
# Cleaning summary:
#   Original shape: (65271, 30)
#   Cleaned shape: (65271, 30)
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65271 entries, 0 to 65270
# Data columns (total 30 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   dispute_number                                                                 65271 non-null  object
#  1   dli_number                                                                     65271 non-null  object
#  2   payment_determination_outcome                                                  65271 non-null  object
#  3   default_decision                                                               65254 non-null  object
#  4   type_of_dispute                                                                65271 non-null  object
#  5   provider/facility_group_name                                                   65271 non-null  object
#  6   provider/facility_name                                                         65271 non-null  object
#  7   provider_email_domain                                                          65271 non-null  object
#  8   provider/facility_npi_number                                                   65271 non-null  object
#  9   practice/facility_size                                                         65271 non-null  object
#  10  health_plan/issuer_name                                                        65271 non-null  object
#  11  health_plan/issuer_email_domain                                                65271 non-null  object
#  12  health_plan_type                                                               65271 non-null  object
#  13  length_of_time_to_make_determination                                           65271 non-null  int64
#  14  idre_compensation                                                              65271 non-null  object
#  15  dispute_line_item_type                                                         65271 non-null  object
#  16  type_of_service_code                                                           65164 non-null  object
#  17  service_code                                                                   65269 non-null  object
#  18  place_of_service_code                                                          64677 non-null  float64
#  19  item_or_service_description                                                    65164 non-null  object
#  20  location_of_service                                                            64677 non-null  object
#  21  practice/facility_specialty_or_type                                            65271 non-null  object
#  22  provider/facility_offer_as_percent_of_qpa                                      58286 non-null  object
#  23  health_plan/issuer_offer_as_percent_of_qpa                                     53524 non-null  object
#  24  offer_selected_from_provider_or_issuer                                         65271 non-null  object
#  25  prevailing_party_offer_as_percent_of_qpa                                       65103 non-null  object
#  26  qpa_as_percent_of_median_qpa                                                   65271 non-null  object
#  27  provider/facility_offer_as_percent_of_median_provider/facility_offer_amount    65271 non-null  object
#  28  health_plan/issuer_offer_as_percent_of_median_health_plan/issuer_offer_amount  65271 non-null  object
#  29  prevailing_offer_as_percent_of_median_prevailing_offer_amount                  65271 non-null  object
# dtypes: float64(1), int64(1), object(28)
# memory usage: 14.9+ MB
#
# Summary statistics:
#        length_of_time_to_make_determination  place_of_service_code
# count                          65271.000000           64677.000000
# mean                              61.032419              22.406342
# std                               29.997159               1.444833
# min                               13.000000               0.000000
# 25%                               41.000000              22.000000
# 50%                               52.000000              23.000000
# 75%                               73.000000              23.000000
# max                              210.000000              82.000000
# Missing values per column:
# dispute_number                                                                       0
# dli_number                                                                           0
# payment_determination_outcome                                                        0
# default_decision                                                                    17
# type_of_dispute                                                                      0
# provider/facility_group_name                                                         0
# provider/facility_name                                                               0
# provider_email_domain                                                                0
# provider/facility_npi_number                                                         0
# practice/facility_size                                                               0
# health_plan/issuer_name                                                              0
# health_plan/issuer_email_domain                                                      0
# health_plan_type                                                                     0
# length_of_time_to_make_determination                                                 0
# idre_compensation                                                                    0
# dispute_line_item_type                                                               0
# type_of_service_code                                                               107
# service_code                                                                         2
# place_of_service_code                                                              594
# item_or_service_description                                                        107
# location_of_service                                                                594
# practice/facility_specialty_or_type                                                  0
# provider/facility_offer_as_percent_of_qpa                                         6985
# health_plan/issuer_offer_as_percent_of_qpa                                       11747
# offer_selected_from_provider_or_issuer                                               0
# prevailing_party_offer_as_percent_of_qpa                                           168
# qpa_as_percent_of_median_qpa                                                         0
# provider/facility_offer_as_percent_of_median_provider/facility_offer_amount          0
# health_plan/issuer_offer_as_percent_of_median_health_plan/issuer_offer_amount        0
# prevailing_offer_as_percent_of_median_prevailing_offer_amount                        0
# dtype: int64
# Numeric columns: ['length_of_time_to_make_determination', 'place_of_service_code']
# Categorical columns: ['dispute_number', 'dli_number', 'payment_determination_outcome', 'default_decision', 'type_of_dispute', 'provider/facility_group_name', 'provider/facility_name', 'provider_email_domain', 'provider/facility_npi_number', 'practice/facility_size', 'health_plan/issuer_name', 'health_plan/issuer_email_domain', 'health_plan_type', 'idre_compensation', 'dispute_line_item_type', 'type_of_service_code', 'service_code', 'item_or_service_description', 'location_of_service', 'practice/facility_specialty_or_type', 'provider/facility_offer_as_percent_of_qpa', 'health_plan/issuer_offer_as_percent_of_qpa', 'offer_selected_from_provider_or_issuer', 'prevailing_party_offer_as_percent_of_qpa', 'qpa_as_percent_of_median_qpa', 'provider/facility_offer_as_percent_of_median_provider/facility_offer_amount', 'health_plan/issuer_offer_as_percent_of_median_health_plan/issuer_offer_amount', 'prevailing_offer_as_percent_of_median_prevailing_offer_amount']
#
# Unique values in dispute_number:
# dispute_number
# DISP-163082    330
# DISP-128485    318
# DISP-110576    221
# DISP-148607    196
# DISP-110744    185
#               ...
# DISP-206790      1
# DISP-206609      1
# DISP-206658      1
# DISP-206619      1
# DISP-206744      1
# Name: count, Length: 24289, dtype: int64
# Unique values in dli_number:
# dli_number
# DLI - 581619    1
# DLI - 582653    1
# DLI - 582530    1
# DLI - 582345    1
# DLI - 582547    1
#                ..
# DLI - 673064    1
# DLI - 582689    1
# DLI - 582679    1
# DLI - 582776    1
# DLI - 582294    1
# Name: count, Length: 65271, dtype: int64
# Unique values in payment_determination_outcome:
# payment_determination_outcome
# In Favor of Provider/Facility/AA Provider    44543
# In Favor of Plan/Issuer                      20544
# NR                                              95
# Split Decision                                  89
# Name: count, dtype: int64

# %% [markdown]
# # This is a key step where I filtered out of batched and bundled cases, leaving us with Single cases only

# %%
# Filter the main dataframe to include only 'Single' cases
# First, let's check the unique values in the "Type of Dispute" column
print("Unique values in 'Type of Dispute' column:")
print(df["Type of Dispute"].unique())

# Now filter for only Single cases
df_single = df[df["Type of Dispute"] == "Single"]
print(f"\nFiltered for Single cases only")
print(f"Original dataframe shape: {df.shape}")
print(f"Filtered dataframe shape: {df_single.shape}")
print(f"Percentage of Single cases: {df_single.shape[0]/df.shape[0]*100:.2f}%")

# Display the first few rows of the filtered data
print("\nFirst 5 rows of filtered data:")
df_single.head()
# Out:
# Unique values in 'Type of Dispute' column:
# ['Single' 'Batched']
#
# Filtered for Single cases only
# Original dataframe shape: (65271, 30)
# Filtered dataframe shape: (21917, 30)
# Percentage of Single cases: 33.58%
#
# First 5 rows of filtered data:
#   Dispute Number    DLI Number              Payment Determination Outcome  \
# 0    DISP-135724  DLI - 582653                    In Favor of Plan/Issuer
# 1    DISP-135637  DLI - 582530                    In Favor of Plan/Issuer
# 2    DISP-135495  DLI - 582345  In Favor of Provider/Facility/AA Provider
# 3    DISP-135654  DLI - 582547  In Favor of Provider/Facility/AA Provider
# 6    DISP-135439  DLI - 582252  In Favor of Provider/Facility/AA Provider
#
#   Default Decision Type of Dispute              Provider/Facility Group Name  \
# 0               No          Single  LONGHORN EMERGENCY MEDICAL ASSOCIATES PA
# 1               No          Single                                        NR
# 2               No          Single            WOODLANDS EMERGENCY PHYSICIANS
# 3               No          Single                  APP OF TENNESSEE ED PLLC
# 6               No          Single               EMERGIGROUP PHYS ASSOC PLLC
#
#            Provider/Facility Name Provider Email Domain  \
# 0          BLUDWORTH MD,WHITNEY G        teamhealth.com
# 1    ROXBOROUGH MEMORIAL HOSPITAL   primehealthcare.com
# 2  WOODLANDS EMERGENCY PHYSICIANS             r1rcm.com
# 3        APP OF TENNESSEE ED PLLC             r1rcm.com
# 6     EMERGIGROUP PHYS ASSOC PLLC             r1rcm.com
#
#   Provider/Facility NPI Number Practice/Facility Size  ...  \
# 0                   1649669672      101-500 Employees  ...
# 1                           NR     Over 500 Employees  ...
# 2                   1467989871       51-100 Employees  ...
# 3                   1003230236      101-500 Employees  ...
# 6                   1831142769       51-100 Employees  ...
#
#   Location of Service Practice/Facility Specialty or Type  \
# 0                  TX                  EMERGENCY MEDICINE
# 1                  PA                 ACUTE CARE HOSPITAL
# 2                  TX                  Emergency Provider
# 3                  TN                   EmergencyMedicine
# 6                  TX                  Emergency Provider
#
#   Provider/Facility Offer as Percent of QPA  \
# 0                                      1.64
# 1                                      5.13
# 2                                      3.19
# 3                                      2.47
# 6                                      3.06
#
#    Health Plan/Issuer Offer as Percent of QPA  \
# 0                                           1
# 1                                         0.7
# 2                                        1.15
# 3                                        1.15
# 6                                         1.1
#
#       Offer Selected from Provider or Issuer  \
# 0                    In Favor of Plan/Issuer
# 1                    In Favor of Plan/Issuer
# 2  In Favor of Provider/Facility/AA Provider
# 3  In Favor of Provider/Facility/AA Provider
# 6  In Favor of Provider/Facility/AA Provider
#
#   Prevailing Party Offer as Percent of QPA QPA as Percent of Median QPA  \
# 0                                        1                            1
# 1                                      0.7                            1
# 2                                     3.19                         0.27
# 3                                     2.47                         0.96
# 6                                     3.06                         0.28
#
#   Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount  \
# 0                                               0.99
# 1                                                  1
# 2                                               0.83
# 3                                               0.71
# 6                                               0.83
#
#    Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount  \
# 0                                                  1
# 1                                                  1
# 2                                               0.92
# 3                                               1.15
# 6                                               0.92
#
#   Prevailing Offer as Percent of Median Prevailing Offer Amount
# 0                                                  1
# 1                                                  1
# 2                                               0.88
# 3                                               0.71
# 6                                               0.88
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Implementing a data transformation step to address columns with non-uniform data type mismatch

# %%
# Identify columns with mixed types
def find_mixed_type_columns(df_single):
    mixed_cols = []
    for col in df_single.columns:
        if df_single[col].apply(type).nunique() > 1:
            mixed_cols.append(col)
    return mixed_cols

mixed_cols = find_mixed_type_columns(df_single)
print("Columns with mixed types:", mixed_cols)
# Out:
# Columns with mixed types: ['Default Decision', 'Provider/Facility NPI Number', 'IDRE Compensation', 'Type of Service Code', 'Service Code', 'Item or Service Description', 'Location of Service', 'Provider/Facility Offer as Percent of QPA', 'Health Plan/Issuer Offer as Percent of QPA', 'Prevailing Party Offer as Percent of QPA', 'QPA as Percent of Median QPA', 'Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount', 'Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount', 'Prevailing Offer as Percent of Median Prevailing Offer Amount']

# %%
# Importing functions from modeling.py
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, r2_score, mean_squared_error
from typing import List

# Use the main preprocessing pipeline file(s)
# Import functions from your modeling.py file
from modeling import (
    get_numeric_and_categorical_columns,
    create_preprocessing_pipeline,
    TypeUnifier
)

# Check for mixed type columns in df_single
def find_mixed_type_columns(df):
    mixed_cols = []
    for col in df.columns:
        if df[col].apply(type).nunique() > 1:
            mixed_cols.append(col)
    return mixed_cols

# Display information about df_single
print("DataFrame shape:", df_single.shape)
print("\nSample of the data:")
display(df_single.head())

# Check data types and mixed columns
print("\nData types in df_single:")
print(df_single.dtypes)

mixed_cols = find_mixed_type_columns(df_single)
print(f"\nFound {len(mixed_cols)} columns with mixed types:")
print(mixed_cols)

# Get numeric and categorical columns
numeric_cols, categorical_cols = get_numeric_and_categorical_columns(df_single)
print(f"\nIdentified {len(numeric_cols)} numeric columns and {len(categorical_cols)} categorical columns")
print(f"Number of numeric columns: {len(numeric_cols)}")
print(f"Number of categorical columns: {len(categorical_cols)}")

# Create the preprocessing pipeline
preprocessor = create_preprocessing_pipeline(numeric_cols, categorical_cols)
print("\nPreprocessing pipeline created successfully")

# Test the preprocessor on a small sample to ensure it works
sample_size = min(1000, len(df_single))
df_sample = df_single.sample(sample_size, random_state=42)

try:
    # Fit and transform the sample
    processed_sample = preprocessor.fit_transform(df_sample)
    print("\nPreprocessing test successful!")
    print(f"Processed sample shape: {processed_sample.shape}")
    
    # If you want to see the feature names after preprocessing
    try:
        feature_names = preprocessor.get_feature_names_out()
        print(f"\nNumber of features after preprocessing: {len(feature_names)}")
        print("First 10 feature names:", feature_names[:10])
    except:
        print("\nCouldn't get feature names, but preprocessing was successful.")
        
except Exception as e:
    print(f"\nError during preprocessing test: {e}")

# Assuming evaluate_classification_models and evaluate_regression_models are imported from modeling.py. This is for later analyses.

# If the data are already loaded and split into X and y (which shouldn't be the case yet); would be good to protect the target variable
# X = df.drop('target_column', axis=1)
# y = df['target_column']
# Out:
# DataFrame shape: (21917, 30)
#
# Sample of the data:
#   Dispute Number    DLI Number              Payment Determination Outcome  \
# 0    DISP-135724  DLI - 582653                    In Favor of Plan/Issuer
# 1    DISP-135637  DLI - 582530                    In Favor of Plan/Issuer
# 2    DISP-135495  DLI - 582345  In Favor of Provider/Facility/AA Provider
# 3    DISP-135654  DLI - 582547  In Favor of Provider/Facility/AA Provider
# 6    DISP-135439  DLI - 582252  In Favor of Provider/Facility/AA Provider
#
#   Default Decision Type of Dispute              Provider/Facility Group Name  \
# 0               No          Single  LONGHORN EMERGENCY MEDICAL ASSOCIATES PA
# 1               No          Single                                        NR
# 2               No          Single            WOODLANDS EMERGENCY PHYSICIANS
# 3               No          Single                  APP OF TENNESSEE ED PLLC
# 6               No          Single               EMERGIGROUP PHYS ASSOC PLLC
#
#            Provider/Facility Name Provider Email Domain  \
# 0          BLUDWORTH MD,WHITNEY G        teamhealth.com
# 1    ROXBOROUGH MEMORIAL HOSPITAL   primehealthcare.com
# 2  WOODLANDS EMERGENCY PHYSICIANS             r1rcm.com
# 3        APP OF TENNESSEE ED PLLC             r1rcm.com
# 6     EMERGIGROUP PHYS ASSOC PLLC             r1rcm.com
#
#   Provider/Facility NPI Number Practice/Facility Size  ...  \
# 0                   1649669672      101-500 Employees  ...
# 1                           NR     Over 500 Employees  ...
# 2                   1467989871       51-100 Employees  ...
# 3                   1003230236      101-500 Employees  ...
# 6                   1831142769       51-100 Employees  ...
#
#   Location of Service Practice/Facility Specialty or Type  \
# 0                  TX                  EMERGENCY MEDICINE
# 1                  PA                 ACUTE CARE HOSPITAL
# 2                  TX                  Emergency Provider
# 3                  TN                   EmergencyMedicine
# 6                  TX                  Emergency Provider
#
#   Provider/Facility Offer as Percent of QPA  \
# 0                                      1.64
# 1                                      5.13
# 2                                      3.19
# 3                                      2.47
# 6                                      3.06
#
#    Health Plan/Issuer Offer as Percent of QPA  \
# 0                                           1
# 1                                         0.7
# 2                                        1.15
# 3                                        1.15
# 6                                         1.1
#
#       Offer Selected from Provider or Issuer  \
# 0                    In Favor of Plan/Issuer
# 1                    In Favor of Plan/Issuer
# 2  In Favor of Provider/Facility/AA Provider
# 3  In Favor of Provider/Facility/AA Provider
# 6  In Favor of Provider/Facility/AA Provider
#
#   Prevailing Party Offer as Percent of QPA QPA as Percent of Median QPA  \
# 0                                        1                            1
# 1                                      0.7                            1
# 2                                     3.19                         0.27
# 3                                     2.47                         0.96
# 6                                     3.06                         0.28
#
#   Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount  \
# 0                                               0.99
# 1                                                  1
# 2                                               0.83
# 3                                               0.71
# 6                                               0.83
#
#    Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount  \
# 0                                                  1
# 1                                                  1
# 2                                               0.92
# 3                                               1.15
# 6                                               0.92
#
#   Prevailing Offer as Percent of Median Prevailing Offer Amount
# 0                                                  1
# 1                                                  1
# 2                                               0.88
# 3                                               0.71
# 6                                               0.88
#
# [5 rows x 30 columns]
# Data types in df_single:
# Dispute Number                                                                    object
# DLI Number                                                                        object
# Payment Determination Outcome                                                     object
# Default Decision                                                                  object
# Type of Dispute                                                                   object
# Provider/Facility Group Name                                                      object
# Provider/Facility Name                                                            object
# Provider Email Domain                                                             object
# Provider/Facility NPI Number                                                      object
# Practice/Facility Size                                                            object
# Health Plan/Issuer Name                                                           object
# Health Plan/Issuer Email Domain                                                   object
# Health Plan Type                                                                  object
# Length of Time to Make Determination                                               int64
# IDRE Compensation                                                                 object
# Dispute Line Item Type                                                            object
# Type of Service Code                                                              object
# Service Code                                                                      object
# Place of Service Code                                                            float64
# Item or Service Description                                                       object
# Location of Service                                                               object
# Practice/Facility Specialty or Type                                               object
# Provider/Facility Offer as Percent of QPA                                         object
# Health Plan/Issuer Offer as Percent of QPA                                        object
# Offer Selected from Provider or Issuer                                            object
# Prevailing Party Offer as Percent of QPA                                          object
# QPA as Percent of Median QPA                                                      object
# Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount       object
# Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount     object
# Prevailing Offer as Percent of Median Prevailing Offer Amount                     object
# dtype: object
#
# Found 14 columns with mixed types:
# ['Default Decision', 'Provider/Facility NPI Number', 'IDRE Compensation', 'Type of Service Code', 'Service Code', 'Item or Service Description', 'Location of Service', 'Provider/Facility Offer as Percent of QPA', 'Health Plan/Issuer Offer as Percent of QPA', 'Prevailing Party Offer as Percent of QPA', 'QPA as Percent of Median QPA', 'Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount', 'Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount', 'Prevailing Offer as Percent of Median Prevailing Offer Amount']
#
# Identified 2 numeric columns and 28 categorical columns
# Number of numeric columns: 2
# Number of categorical columns: 28
#
# Preprocessing pipeline created successfully
#
# Preprocessing test successful!
# Processed sample shape: (1000, 5380)
#
# Couldn't get feature names, but preprocessing was successful.

# %%
# Addressing Place of Service, by starting with printing the original data type
print("Original data type:", df_single['Place of Service Code'].dtype)

# Making a clean copy first to avoid the SettingWithCopyWarning
df_single = df_single.copy()

# Step 1: Convert to string first (this preserves NaN as NaN)
df_single.loc[:, 'pos_code_str'] = df_single['Place of Service Code'].astype(str)

# Step 2: Replace 'nan' strings with 'Unknown'
df_single.loc[df_single['pos_code_str'] == 'nan', 'pos_code_str'] = 'Unknown'

# Step 3: Remove the decimal points from the codes
df_single.loc[:, 'pos_code_str'] = df_single['pos_code_str'].replace(r'\.0$', '', regex=True)

print("Sample values after conversion:", df_single['pos_code_str'].head())

# Step 4: Create a mapping dictionary with common POS codes
pos_mapping = {
    '11': 'Office',
    '21': 'Inpatient Hospital',
    '22': 'Outpatient Hospital',
    '23': 'Emergency Room - Hospital',
    '31': 'Skilled Nursing Facility',
    '32': 'Nursing Facility',
    '33': 'Custodial Care Facility',
    '65': 'End-Stage Renal Disease Treatment Facility',
    '81': 'Independent Laboratory',
    'Unknown': 'Missing POS Code'
    # Add others as needed for your dataset
}

# Step 5: Create a new column with descriptions
df_single.loc[:, 'pos_description'] = df_single['pos_code_str'].map(pos_mapping)

# Print the results to check if mapping worked correctly
print("\nCheck if mapping worked correctly:")
print(df_single[['Place of Service Code', 'pos_code_str', 'pos_description']].head(10))

# Check if there are any missing mappings
missing_mappings = df_single['pos_description'].isna().sum()
print(f"\nNumber of records with missing mappings: {missing_mappings}")

if missing_mappings > 0:
    print("Unique POS codes without mappings:")
    unmapped_codes = df_single[df_single['pos_description'].isna()]['pos_code_str'].unique()
    print(sorted(unmapped_codes))
    
    # Optional: Handle any missing mappings
    df_single.loc[:, 'pos_description'] = df_single['pos_description'].fillna('Other/Unknown POS')
    
# Optional: Convert the string column to categorical for efficiency
df_single.loc[:, 'pos_code_cat'] = df_single['pos_code_str'].astype('category')
print("\nNew categorical column data type:", df_single['pos_code_cat'].dtype)

# Optionally, update the unmapped codes in your mapping dictionary
print("\nYou may want to add these codes to your mapping dictionary:")
for code in sorted(unmapped_codes):
    print(f"    '{code}': '',")
# Out:
# Original data type: float64
# Sample values after conversion: 0    23
# 1    23
# 2    23
# 3    23
# 6    23
# Name: pos_code_str, dtype: object
#
# Check if mapping worked correctly:
#     Place of Service Code pos_code_str            pos_description
# 0                    23.0           23  Emergency Room - Hospital
# 1                    23.0           23  Emergency Room - Hospital
# 2                    23.0           23  Emergency Room - Hospital
# 3                    23.0           23  Emergency Room - Hospital
# 6                    23.0           23  Emergency Room - Hospital
# 7                    23.0           23  Emergency Room - Hospital
# 8                    23.0           23  Emergency Room - Hospital
# 9                    23.0           23  Emergency Room - Hospital
# 10                   23.0           23  Emergency Room - Hospital
# 11                   23.0           23  Emergency Room - Hospital
#
# Number of records with missing mappings: 722
# Unique POS codes without mappings:
# ['0', '12', '15', '19', '2', '20', '24', '26', '42']
#
# New categorical column data type: category
#
# You may want to add these codes to your mapping dictionary:
#     '0': '',
#     '12': '',
#     '15': '',
#     '19': '',
#     '2': '',
#     '20': '',
#     '24': '',
#     '26': '',
#     '42': '',

# %%
# 1. Standard approach - identify obvious categorical columns
obvious_categorical_cols = df_single.select_dtypes(include=['object', 'category']).columns.tolist()
print(f"Obvious categorical columns: {len(obvious_categorical_cols)}")

# 2. Identify potential numeric categorical variables
# Look for integer columns with few unique values (likely categorical)
numeric_cols = df_single.select_dtypes(include=['int64', 'float64']).columns.tolist()
potential_categorical = []

for col in numeric_cols:
    unique_count = df_single[col].nunique()
    # If column has relatively few unique values, it might be categorical
    if unique_count < 20:  # Threshold can be adjusted
        potential_categorical.append(col)
        print(f"Potential categorical column: {col} with {unique_count} unique values")

# 3. Combine all categorical variables
all_categorical = obvious_categorical_cols + potential_categorical
print(f"\nTotal categorical columns identified: {len(all_categorical)}")

# 4. Analyze each categorical variable
for col in all_categorical:
    # Get value counts
    value_counts = df_single[col].value_counts().sort_values(ascending=False)
    # Calculate percentage
    value_percent = df_single[col].value_counts(normalize=True).sort_values(ascending=False) * 100
    
    print(f"\n{'='*50}")
    print(f"Analysis of '{col}':")
    print(f"Number of unique values: {df_single[col].nunique()}")
    print(f"Missing values: {df_single[col].isna().sum()} ({df_single[col].isna().mean()*100:.2f}%)")
    
    # Show top categories
    print(f"\nTop categories (showing up to 10):")
    
    # Combine counts and percentages
    summary = pd.DataFrame({
        'Count': value_counts,
        'Percentage': value_percent
    }).head(10)
    
    print(summary)
    
    # Visualize if there are not too many categories
    if df_single[col].nunique() <= 15:
        plt.figure(figsize=(10, 6))
        sns.countplot(y=col, data=df_single, order=value_counts.index[:15])
        plt.title(f'Distribution of {col}')
        plt.xlabel('Count')
        plt.tight_layout()
        plt.savefig(f'categorical_dist_{col.replace("/", "_")}.png')
        plt.close()
# Out:
# Obvious categorical columns: 31
# Potential categorical column: Place of Service Code with 16 unique values
#
# Total categorical columns identified: 32
#
# ==================================================
# Analysis of 'Dispute Number':
# Number of unique values: 18131
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                 Count  Percentage
# Dispute Number
# DISP-226234        45    0.205320
# DISP-211665        43    0.196195
# DISP-188889        41    0.187069
# DISP-223998        41    0.187069
# DISP-153310        39    0.177944
# DISP-204150        37    0.168819
# DISP-202647        36    0.164256
# DISP-195408        35    0.159693
# DISP-161288        34    0.155131
# DISP-176235        33    0.150568
#
# ==================================================
# Analysis of 'DLI Number':
# Number of unique values: 21917
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#               Count  Percentage
# DLI Number
# DLI - 582665      1    0.004563
# DLI - 581619      1    0.004563
# DLI - 582653      1    0.004563
# DLI - 582530      1    0.004563
# DLI - 582345      1    0.004563
# DLI - 582547      1    0.004563
# DLI - 582252      1    0.004563
# DLI - 582294      1    0.004563
# DLI - 582776      1    0.004563
# DLI - 582679      1    0.004563
#
# ==================================================
# Analysis of 'Payment Determination Outcome':
# Number of unique values: 4
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                            Count  Percentage
# Payment Determination Outcome
# In Favor of Provider/Facility/AA Provider  14555   66.409636
# In Favor of Plan/Issuer                     7346   33.517361
# NR                                            13    0.059315
# Split Decision                                 3    0.013688
#
# ==================================================
# Analysis of 'Default Decision':
# Number of unique values: 3
# Missing values: 17 (0.08%)
#
# Top categories (showing up to 10):
#                   Count  Percentage
# Default Decision
# No                17820   81.369863
# Yes                3502   15.990868
# NR                  578    2.639269
#
# ==================================================
# Analysis of 'Type of Dispute':
# Number of unique values: 1
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                  Count  Percentage
# Type of Dispute
# Single           21917       100.0
#
# ==================================================
# Analysis of 'Provider/Facility Group Name':
# Number of unique values: 1006
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                           Count  Percentage
# Provider/Facility Group Name
# NR                                         5720   26.098462
# Singleton Associates, P.A.                  551    2.514030
# EMERGENCY COVERAGE CORPORATION              460    2.098827
# SOUTHEASTERN EMERGENCY PHYSICIANS LLC       442    2.016699
# Providence Anesthesiology Associates, PA    397    1.811379
# Coweta Emergency Group, LLC                 371    1.692750
# Lake Spring Emergency Group, LLC            357    1.628873
# INPHYNET SOUTH BROWARD LLC                  330    1.505681
# Radiology Alliance, P.C.                    312    1.423552
# Empire State Radiology, P.C.                290    1.323174
#
# ==================================================
# Analysis of 'Provider/Facility Name':
# Number of unique values: 2987
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                           Count  Percentage
# Provider/Facility Name
# Lumberton Hospital, LLC                     855    3.901081
# Singleton Associates, P.A.                  552    2.518593
# Providence Anesthesiology Associates, PA    406    1.852443
# Coweta Emergency Group, LLC                 371    1.692750
# Altus Lake Jackson, LP                      368    1.679062
# Lake Spring Emergency Group, LLC            348    1.587809
# Radiology Alliance, P.C.                    317    1.446366
# North Broward Hospital District             298    1.359675
# Empire State Radiology, P.C.                289    1.318611
# Imaging Associates of Indiana, PC           262    1.195419
#
# ==================================================
# Analysis of 'Provider Email Domain':
# Number of unique values: 142
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                        Count  Percentage
# Provider Email Domain
# scp-health.com          3605   16.448419
# teamhealth.com          2542   11.598303
# agshealth.com           2282   10.412009
# altushealthsystem.com   1912    8.723822
# r1rcm.com               1676    7.647032
# wincherbilling.com      1314    5.995346
# callagylaw.com           787    3.590820
# hcahealthcare.com        572    2.609846
# saparm.com               552    2.518593
# roundtmc.com             551    2.514030
#
# ==================================================
# Analysis of 'Provider/Facility NPI Number':
# Number of unique values: 1191
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                               Count  Percentage
# Provider/Facility NPI Number
# NR                             7705   35.155359
# 1750932117                     1037    4.731487
# 1538107875                      462    2.107953
# 1275957508                      416    1.898070
# 1427005008                      400    1.825067
# 1356379382                      318    1.450929
# 1861478489                      317    1.446366
# 1396739884                      299    1.364238
# 1649669672                      286    1.304923
# 1316401102                      265    1.209107
#
# ==================================================
# Analysis of 'Practice/Facility Size':
# Number of unique values: 6
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                          Count  Percentage
# Practice/Facility Size
# 51-100 Employees          5501   25.099238
# 101-500 Employees         4515   20.600447
# 20-50 Employees           4284   19.546471
# Fewer than 20 Employees   3054   13.934389
# Over 500 Employees        2901   13.236301
# NR                        1662    7.583155
#
# ==================================================
# Analysis of 'Health Plan/Issuer Name':
# Number of unique values: 622
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                Count  Percentage
# Health Plan/Issuer Name
# United Healthcare               2414   11.014281
# Cigna                           2255   10.288817
# Aetna                           1843    8.408998
# UNITED HEALTHCARE               1689    7.706347
# AETNA                           1336    6.095725
# Anthem Blue Cross Blue Shield   1209    5.516266
# UMR                             1018    4.644796
# Anthem Virginia                  914    4.170279
# UnitedHealthcare                 829    3.782452
# CIGNA                            816    3.723137
#
# ==================================================
# Analysis of 'Health Plan/Issuer Email Domain':
# Number of unique values: 156
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                  Count  Percentage
# Health Plan/Issuer Email Domain
# uhc.com                           5691   25.966145
# aetna.com                         3307   15.088744
# anthem.com                        2700   12.319204
# multiplan.com                     2544   11.607428
# bcbstx.com                        2070    9.444723
# clearhs.com                       1187    5.415887
# bcbst.com                          869    3.964959
# bcbsil.com                         791    3.609071
# cigna.com                          745    3.399188
# horizonblue.com                    337    1.537619
#
# ==================================================
# Analysis of 'Health Plan Type':
# Number of unique values: 6
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                                     Count  Percentage
# Health Plan Type
# Either partially or fully self-insured private ...  13446   61.349637
# Fully insured private group health plan              5420   24.729662
# No Plan/Issuer Response                              1837    8.381622
# Federal Employees Health Benefits (FEHB) Carrier      570    2.600721
# Individual health insurance issuer                    487    2.222019
# Non-federal government plan (or state or local ...    157    0.716339
#
# ==================================================
# Analysis of 'IDRE Compensation':
# Number of unique values: 30
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                    Count  Percentage
# IDRE Compensation
# 365                 8491   38.741616
# 395                 3906   17.821782
# 285                 1778    8.112424
# 350                 1590    7.254643
# 299                 1432    6.533741
# 0                   1421    6.483552
# 500                 1166    5.320071
# 598                  644    2.938358
# 397                  231    1.053976
# 398                  230    1.049414
#
# ==================================================
# Analysis of 'Dispute Line Item Type':
# Number of unique values: 3
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                            Count  Percentage
# Dispute Line Item Type
# Single                     17237   78.646713
# Component Item or Service   3115   14.212712
# Bundled Item or Service     1565    7.140576
#
# ==================================================
# Analysis of 'Type of Service Code':
# Number of unique values: 4
# Missing values: 107 (0.49%)
#
# Top categories (showing up to 10):
#                       Count  Percentage
# Type of Service Code
# CPT                   20501   93.998166
# HCPCS                   798    3.658872
# DRG                     346    1.586428
# NR                      165    0.756534
#
# ==================================================
# Analysis of 'Service Code':
# Number of unique values: 1328
# Missing values: 2 (0.01%)
#
# Top categories (showing up to 10):
#               Count  Percentage
# Service Code
# 99284          4214   19.228839
# 99285          4165   19.005248
# 99283          2692   12.283824
# 99291           429    1.957563
# 95941           346    1.578827
# 95938           327    1.492129
# 74177           322    1.469313
# 74176           224    1.022131
# 95939           200    0.912617
# 85025           161    0.734657
#
# ==================================================
# Analysis of 'Item or Service Description':
# Number of unique values: 1235
# Missing values: 107 (0.49%)
#
# Top categories (showing up to 10):
#                                                     Count  Percentage
# Item or Service Description
# Emergency department visit for problem of high ...   4262   19.541495
# Emergency department visit for life threatening...   4196   19.238881
# Emergency department visit for problem of moder...   2707   12.411738
# Critical care, first 30-74 minutes                    432    1.980743
# Continuous remote monitoring of nervous system ...    349    1.600183
# Placement of skin electrodes and measurement of...    332    1.522238
# CT scan of abdomen and pelvis with contrast           322    1.476387
# CT scan of abdomen and pelvis without contrast        224    1.027052
# Placement of skin electrodes and measurement of...    203    0.930766
# Complete blood cell count (red cells, white blo...    161    0.738193
#
# ==================================================
# Analysis of 'Location of Service':
# Number of unique values: 48
# Missing values: 594 (2.71%)
#
# Top categories (showing up to 10):
#                      Count  Percentage
# Location of Service
# TX                    6980   32.734606
# GA                    1880    8.816771
# TN                    1729    8.108615
# FL                    1623    7.611499
# VA                    1218    5.712142
# NY                     983    4.610045
# NJ                     957    4.488111
# NC                     955    4.478732
# AZ                     817    3.831543
# IN                     599    2.809173
#
# ==================================================
# Analysis of 'Practice/Facility Specialty or Type':
# Number of unique values: 433
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                      Count  Percentage
# Practice/Facility Specialty or Type
# Emergency Medicine                    5835   26.623169
# NR                                    4834   22.055938
# Radiology                             1948    8.888078
# EMERGENCY MEDICINE                    1820    8.304056
# Emergency Provider                     546    2.491217
# ANESTHESIA                             422    1.925446
# Hospital                               387    1.765753
# EMERGENCY SERVICES                     376    1.715563
# Neonatal-Perinatal Medicine            358    1.633435
# ED                                     312    1.423552
#
# ==================================================
# Analysis of 'Provider/Facility Offer as Percent of QPA':
# Number of unique values: 1682
# Missing values: 4421 (20.17%)
#
# Top categories (showing up to 10):
#                                            Count  Percentage
# Provider/Facility Offer as Percent of QPA
# +                                           1524    8.710562
# NR                                           720    4.115226
# 1                                            227    1.297439
# 3.19                                         180    1.028807
# 3.2                                          174    0.994513
# 2.76                                         159    0.908779
# 1.7                                          149    0.851623
# 1.65                                         144    0.823045
# 3                                            135    0.771605
# 3.47                                         130    0.743027
#
# ==================================================
# Analysis of 'Health Plan/Issuer Offer as Percent of QPA':
# Number of unique values: 365
# Missing values: 5264 (24.02%)
#
# Top categories (showing up to 10):
#                                             Count  Percentage
# Health Plan/Issuer Offer as Percent of QPA
# 1                                            8311   49.906924
# +                                            1524    9.151504
# 1.05                                         1155    6.935687
# 1.25                                          646    3.879181
# NR                                            487    2.924398
# 1.1                                           391    2.347925
# 0                                             221    1.327088
# 1.15                                          207    1.243019
# 1.29                                          139    0.834684
# 1.38                                          117    0.702576
#
# ==================================================
# Analysis of 'Offer Selected from Provider or Issuer':
# Number of unique values: 3
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                            Count  Percentage
# Offer Selected from Provider or Issuer
# In Favor of Provider/Facility/AA Provider  13412   61.194507
# In Favor of Plan/Issuer                     5334   24.337272
# NR                                          3171   14.468221
#
# ==================================================
# Analysis of 'Prevailing Party Offer as Percent of QPA':
# Number of unique values: 1453
# Missing values: 25 (0.11%)
#
# Top categories (showing up to 10):
#                                           Count  Percentage
# Prevailing Party Offer as Percent of QPA
# NR                                         4048   18.490773
# 1                                          2605   11.899324
# +                                          1524    6.961447
# 1.05                                        461    2.105792
# 3.19                                        161    0.735428
# 3.2                                         159    0.726293
# 2.76                                        148    0.676046
# 1.25                                        141    0.644071
# 3                                           135    0.616664
# 1.7                                         133    0.607528
#
# ==================================================
# Analysis of 'QPA as Percent of Median QPA':
# Number of unique values: 783
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                               Count  Percentage
# QPA as Percent of Median QPA
# NR                             7118   32.477073
# 1                              5451   24.871105
# 1.05                            208    0.949035
# 1.13                            200    0.912534
# 1.01                            170    0.775654
# 0.93                            154    0.702651
# 1.53                            151    0.688963
# 0.77                            144    0.657024
# 0.86                            136    0.620523
# 0.85                            133    0.606835
#
# ==================================================
# Analysis of 'Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount':
# Number of unique values: 805
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                                     Count  Percentage
# Provider/Facility Offer as Percent of Median Pr...
# 1                                                    8828   40.279235
# NR                                                   6733   30.720445
# 1.04                                                  241    1.099603
# 1.02                                                  168    0.766528
# 0.99                                                  168    0.766528
# 0.83                                                  117    0.533832
# 1.03                                                  112    0.511019
# 0                                                     107    0.488206
# 1.06                                                  101    0.460829
# 1.28                                                   99    0.451704
#
# ==================================================
# Analysis of 'Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount':
# Number of unique values: 920
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                                     Count  Percentage
# Health Plan/Issuer Offer as Percent of Median H...
# NR                                                   5939   27.097687
# 1                                                    5383   24.560843
# 0                                                     197    0.898846
# 1.01                                                  183    0.834968
# 1.05                                                  176    0.803030
# 0.87                                                  152    0.693526
# 0.93                                                  150    0.684400
# 0.83                                                  147    0.670712
# 0.95                                                  146    0.666150
# 0.96                                                  142    0.647899
#
# ==================================================
# Analysis of 'Prevailing Offer as Percent of Median Prevailing Offer Amount':
# Number of unique values: 856
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                                                     Count  Percentage
# Prevailing Offer as Percent of Median Prevailin...
# 1                                                    7573   34.553087
# NR                                                   5633   25.701510
# 1.08                                                  197    0.898846
# 1.04                                                  175    0.798467
# 1.19                                                  146    0.666150
# 1.02                                                  144    0.657024
# 1.45                                                  105    0.479080
# 0.88                                                  104    0.474517
# 1.01                                                   90    0.410640
# 1.28                                                   86    0.392389
#
# ==================================================
# Analysis of 'pos_code_str':
# Number of unique values: 17
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#               Count  Percentage
# pos_code_str
# 23            16112   73.513711
# 21             2763   12.606652
# 22             1715    7.824976
# 24              647    2.952046
# Unknown         594    2.710225
# 19               59    0.269197
# 11                6    0.027376
# 26                5    0.022813
# 0                 5    0.022813
# 81                3    0.013688
#
# ==================================================
# Analysis of 'pos_description':
# Number of unique values: 9
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#                            Count  Percentage
# pos_description
# Emergency Room - Hospital  16112   73.513711
# Inpatient Hospital          2763   12.606652
# Outpatient Hospital         1715    7.824976
# Other/Unknown POS            722    3.294246
# Missing POS Code             594    2.710225
# Office                         6    0.027376
# Independent Laboratory         3    0.013688
# Skilled Nursing Facility       1    0.004563
# Nursing Facility               1    0.004563
#
# ==================================================
# Analysis of 'pos_code_cat':
# Number of unique values: 17
# Missing values: 0 (0.00%)
#
# Top categories (showing up to 10):
#               Count  Percentage
# pos_code_cat
# 23            16112   73.513711
# 21             2763   12.606652
# 22             1715    7.824976
# 24              647    2.952046
# Unknown         594    2.710225
# 19               59    0.269197
# 11                6    0.027376
# 0                 5    0.022813
# 26                5    0.022813
# 81                3    0.013688
#
# ==================================================
# Analysis of 'Place of Service Code':
# Number of unique values: 16
# Missing values: 594 (2.71%)
#
# Top categories (showing up to 10):
#                        Count  Percentage
# Place of Service Code
# 23.0                   16112   75.561600
# 21.0                    2763   12.957839
# 22.0                    1715    8.042958
# 24.0                     647    3.034282
# 19.0                      59    0.276697
# 11.0                       6    0.028139
# 26.0                       5    0.023449
# 0.0                        5    0.023449
# 81.0                       3    0.014069
# 15.0                       2    0.009380

# %%
# Creating some ordering via ordering map for the "Practice/Facility Size" variable
size_order = {
    'Fewer than 20 Employees': 1,
    '20-50 Employees': 2,
    '51-100 Employees': 3,
    '101-500 Employees': 4,
    'Over 500 Employees': 5,
    'NR': 0  # Not Reported - typically assign 0 or NaN
}

# Make an explicit copy to ensure we're not working with a view
df_single = df_single.copy()

# Create ordinal encoding using .loc to avoid the warning
df_single.loc[:, 'facility_size_ordinal'] = df_single['Practice/Facility Size'].map(size_order)

# Check the encoding
print("\nOrdinal encoding created successfully")
print(df_single[['Practice/Facility Size', 'facility_size_ordinal']].drop_duplicates().sort_values('facility_size_ordinal'))

# Handle missing values using .loc
df_single['facility_size_ordinal'] = df_single['facility_size_ordinal'].astype('Int64')
df_single.loc[df_single['facility_size_ordinal'] == 0, 'facility_size_ordinal'] = pd.NA

# For one-hot encoding, create another explicit copy
df_for_encoding = df_single.copy()
df_for_encoding.loc[df_for_encoding['Practice/Facility Size'] == 'NR', 'Practice/Facility Size'] = np.nan

# Now one-hot encode
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore')
facility_size_encoded = encoder.fit_transform(df_for_encoding[['Practice/Facility Size']].fillna('Missing'))

# Get the feature names
feature_names = [f"facility_size_{cat}" for cat in encoder.categories_[0][1:]]

# Create a DataFrame with the encoded columns
facility_size_df = pd.DataFrame(
    facility_size_encoded,
    columns=feature_names,
    index=df_single.index  # Use df_single.index instead of df.index
)

# Now you can add these columns to your main dataframe
df_single = pd.concat([df_single, facility_size_df], axis=1)
print("\nOne-hot encoding created with the following columns:")
print(facility_size_df.columns.tolist())
# Out:
# Ordinal encoding created successfully
#       Practice/Facility Size  facility_size_ordinal
# 134                       NR                      0
# 32   Fewer than 20 Employees                      1
# 7            20-50 Employees                      2
# 2           51-100 Employees                      3
# 0          101-500 Employees                      4
# 1         Over 500 Employees                      5
#
# One-hot encoding created with the following columns:
# ['facility_size_20-50 Employees', 'facility_size_51-100 Employees', 'facility_size_Fewer than 20 Employees', 'facility_size_Missing', 'facility_size_Over 500 Employees']

# %%
# Explore the Payment Determination Outcome variable
print("Distribution of Payment Determination Outcome:")
outcome_counts = df_single['Payment Determination Outcome'].value_counts()
print(outcome_counts)

# Calculate percentages
outcome_pcts = outcome_counts / outcome_counts.sum() * 100
print("\nPercentage distribution:")
for outcome, pct in outcome_pcts.items():
    print(f"{outcome}: {pct:.2f}%")

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=outcome_counts.index, y=outcome_counts.values)
plt.title('Payment Determination Outcomes')
plt.ylabel('Count')
plt.xlabel('Outcome')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Distribution of Payment Determination Outcome:
# Payment Determination Outcome
# In Favor of Provider/Facility/AA Provider    14555
# In Favor of Plan/Issuer                       7346
# NR                                              13
# Split Decision                                   3
# Name: count, dtype: int64
#
# Percentage distribution:
# In Favor of Provider/Facility/AA Provider: 66.41%
# In Favor of Plan/Issuer: 33.52%
# NR: 0.06%
# Split Decision: 0.01%

# %% [markdown]
# ## 3. Data Visualization
#
# Let's visualize the data to understand it better.

# %%
print(df_single.columns.tolist())
# Out:
# ['Dispute Number', 'DLI Number', 'Payment Determination Outcome', 'Default Decision', 'Type of Dispute', 'Provider/Facility Group Name', 'Provider/Facility Name', 'Provider Email Domain', 'Provider/Facility NPI Number', 'Practice/Facility Size', 'Health Plan/Issuer Name', 'Health Plan/Issuer Email Domain', 'Health Plan Type', 'Length of Time to Make Determination', 'IDRE Compensation', 'Dispute Line Item Type', 'Type of Service Code', 'Service Code', 'Place of Service Code', 'Item or Service Description', 'Location of Service', 'Practice/Facility Specialty or Type', 'Provider/Facility Offer as Percent of QPA', 'Health Plan/Issuer Offer as Percent of QPA', 'Offer Selected from Provider or Issuer', 'Prevailing Party Offer as Percent of QPA', 'QPA as Percent of Median QPA', 'Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount', 'Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount', 'Prevailing Offer as Percent of Median Prevailing Offer Amount', 'pos_code_str', 'pos_description', 'pos_code_cat', 'facility_size_ordinal', 'facility_size_20-50 Employees', 'facility_size_51-100 Employees', 'facility_size_Fewer than 20 Employees', 'facility_size_Missing', 'facility_size_Over 500 Employees']

# %%
# Replace 'length_of_time_to_make_determination' with 'Length of Time to Make Determination'
numeric_cols = ['Length of Time to Make Determination']

# %%
# Debug the numeric_cols list
print("Type of numeric_cols:", type(numeric_cols))
print("Contents of numeric_cols:", numeric_cols)

# Filter out any non-string elements
valid_numeric_cols = [col for col in numeric_cols if isinstance(col, str)]
print("After filtering non-strings:", valid_numeric_cols)

# Now use the filtered list
if valid_numeric_cols:
    print("Distribution of numeric features:")
    plot_numeric_distribution(df_single, valid_numeric_cols)
else:
    print("No valid numeric columns to plot after filtering.")
# Out:
# Type of numeric_cols: <class 'list'>
# Contents of numeric_cols: ['Length of Time to Make Determination']
# After filtering non-strings: ['Length of Time to Make Determination']
# Distribution of numeric features:

# %%
# Distribution of numeric features
if numeric_cols:
    print("Distribution of numeric features:")
    plot_numeric_distribution(df_single, numeric_cols)
# Out:
# Distribution of numeric features:

# %%
# Correlation matrix
if len(numeric_cols) > 1:
    print("Correlation matrix:")
    plot_correlation_matrix(df_single, numeric_cols)

# %% [markdown]
# ## 4. Selecting Target Variable
#
# Now, let's select the target variable for our predictive model.

# %%
# List all columns for user to select as target
print("Available columns for target variable:")
for i, col in enumerate(df_single.columns):
    print(f"{i}. {col}")

# Defining our target variable
target_column = 'Payment Determination Outcome'  

# Check data type of target variable to determine if this is a regression or classification problem
if target_column in df_single.columns:
    print(f"\nTarget variable: {target_column}")
    print(f"Data type: {df_single[target_column].dtype}")
    
    # For numeric target, show distribution
    if pd.api.types.is_numeric_dtype(df_single[target_column]):
        print("\nTarget distribution:")
        plt.figure(figsize=(10, 6))
        sns.histplot(df_single[target_column], kde=True)
        plt.title(f'Distribution of {target_column}')
        plt.show()
        
        problem_type = 'regression'
        print("\nThis appears to be a regression problem.")
    else:
        # For categorical target, show value counts
        print("\nTarget value counts:")
        display(df_single[target_column].value_counts())
        
        plt.figure(figsize=(10, 6))
        sns.countplot(y=df_single[target_column])
        plt.title(f'Count of {target_column}')
        plt.show()
        
        problem_type = 'classification'
        print(f"\nThis appears to be a classification problem, in predicting: {target_column}")
else:
    print(f"Error: '{target_column}' not found in the data. Please select a valid column.")
# Out:
# Available columns for target variable:
# 0. Dispute Number
# 1. DLI Number
# 2. Payment Determination Outcome
# 3. Default Decision
# 4. Type of Dispute
# 5. Provider/Facility Group Name
# 6. Provider/Facility Name
# 7. Provider Email Domain
# 8. Provider/Facility NPI Number
# 9. Practice/Facility Size
# 10. Health Plan/Issuer Name
# 11. Health Plan/Issuer Email Domain
# 12. Health Plan Type
# 13. Length of Time to Make Determination
# 14. IDRE Compensation
# 15. Dispute Line Item Type
# 16. Type of Service Code
# 17. Service Code
# 18. Place of Service Code
# 19. Item or Service Description
# 20. Location of Service
# 21. Practice/Facility Specialty or Type
# 22. Provider/Facility Offer as Percent of QPA
# 23. Health Plan/Issuer Offer as Percent of QPA
# 24. Offer Selected from Provider or Issuer
# 25. Prevailing Party Offer as Percent of QPA
# 26. QPA as Percent of Median QPA
# 27. Provider/Facility Offer as Percent of Median Provider/Facility Offer Amount
# 28. Health Plan/Issuer Offer as Percent of Median Health Plan/Issuer Offer Amount
# 29. Prevailing Offer as Percent of Median Prevailing Offer Amount
# 30. pos_code_str
# 31. pos_description
# 32. pos_code_cat
# 33. facility_size_ordinal
# 34. facility_size_20-50 Employees
# 35. facility_size_51-100 Employees
# 36. facility_size_Fewer than 20 Employees
# 37. facility_size_Missing
# 38. facility_size_Over 500 Employees
#
# Target variable: Payment Determination Outcome
# Data type: object
#
# Target value counts:
# Payment Determination Outcome
# In Favor of Provider/Facility/AA Provider    14555
# In Favor of Plan/Issuer                       7346
# NR                                              13
# Split Decision                                   3
# Name: count, dtype: int64
# This appears to be a classification problem, in predicting: Payment Determination Outcome

# %% [markdown]
# ## 5. Data Splitting
#
# Split the data into training and testing sets.

# %%
# Split the data - make sure to use your actual target column name
try:
    X_train, X_test, y_train, y_test = split_data(df_single, target_column)
    
    print(f"Training features shape: {X_train.shape}")
    print(f"Testing features shape: {X_test.shape}")
    print(f"Training target shape: {y_train.shape}")
    print(f"Testing target shape: {y_test.shape}")
except Exception as e:
    print(f"Error: {e}")
    print("Please make sure you've selected a valid target column.")
# Out:
# Data split summary:
#   Training set: 17533 samples
#   Testing set: 4384 samples
# Training features shape: (17533, 38)
# Testing features shape: (4384, 38)
# Training target shape: (17533,)
# Testing target shape: (4384,)

# %% [markdown]
# ## 6. Model Building and Evaluation
#
# Build and evaluate predictive models.

# %%
# Create preprocessing pipeline
numeric_cols, categorical_cols = get_numeric_and_categorical_columns(X_train)
preprocessor = create_preprocessing_pipeline(numeric_cols, categorical_cols)

# Evaluate models based on problem type
if 'problem_type' in locals() and problem_type == 'regression':
    # Evaluate regression models
    print("Evaluating regression models...")
    regression_results = evaluate_regression_models(X_train, y_train, X_test, y_test, preprocessor)
    display(regression_results)
    
    # Plot model comparison
    plt.figure(figsize=(12, 6))
    sns.barplot(x='R²', y='Model', data=regression_results)
    plt.title('Model Comparison - R² Score')
    plt.xlim(0, 1)  # R² typically ranges from 0 to 1
    plt.show()
    
elif 'problem_type' in locals() and problem_type == 'classification':
    # Evaluate classification models
    print("Evaluating classification models...")
    classification_results = evaluate_classification_models(X_train, y_train, X_test, y_test, preprocessor)
    display(classification_results)
    
    # Plot model comparison
    plt.figure(figsize=(12, 6))
    sns.barplot(x='F1 Score', y='Model', data=classification_results)
    plt.title('Model Comparison - F1 Score')
    plt.xlim(0, 1)  # F1 score ranges from 0 to 1
    plt.show()
else:
    print("Please run the previous cell to determine the problem type.")
# Out:
# Evaluating classification models...
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
#                  Model  Accuracy  Precision    Recall  F1 Score  ROC-AUC  \
# 0  Logistic Regression  0.996807   0.996824  0.996807  0.996664      NaN
# 1        Decision Tree  0.996122   0.995979  0.996122  0.996011      NaN
# 2        Random Forest  0.993613   0.992513  0.993613  0.993054      NaN
# 3    Gradient Boosting  0.988595   0.987671  0.988595  0.988066      NaN
# 4                  SVC  0.984489   0.983813  0.984489  0.983997      NaN
# 5                  KNN  0.950274   0.949040  0.950274  0.949484      NaN
#
#    CV Accuracy
# 0     0.995266
# 1     0.996635
# 2     0.994296
# 3     0.988365
# 4     0.983574
# 5     0.937489

# %% [markdown]
# ## 7. Feature Importance
#
# Let's examine which features are most important for the best model.

# %%
# Select the best model based on problem type
if 'problem_type' in locals() and problem_type == 'regression' and 'regression_results' in locals():
    best_model_name = regression_results.iloc[0]['Model']
    print(f"Best regression model: {best_model_name}")
    
    # For tree-based models, we can extract feature importance
    if best_model_name in ['Random Forest', 'Gradient Boosting', 'Decision Tree']:
        # Import and get models
        from modeling import get_regression_models
        models = get_regression_models()
        
        # Get the best model
        best_model = models[best_model_name]
        
        # Create full pipeline
        from sklearn.pipeline import Pipeline
        pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', best_model)])
        
        # Fit model
        pipeline.fit(X_train, y_train)
        
        # Get feature names after preprocessing
        feature_names = numeric_cols.copy()
        # For categorical features, get one-hot encoded column names
        for cat_col in categorical_cols:
            unique_values = X_train[cat_col].unique()
            for value in unique_values:
                feature_names.append(f"{cat_col}_{value}")
        
        # Get feature importances
        importances = pipeline.named_steps['model'].feature_importances_
        
        # Get the right number of feature names
        if len(feature_names) > len(importances):
            feature_names = feature_names[:len(importances)]
        
        # Plot feature importance
        plot_feature_importance(feature_names, importances, title=f"{best_model_name} - Feature Importance")
    
elif 'problem_type' in locals() and problem_type == 'classification' and 'classification_results' in locals():
    best_model_name = classification_results.iloc[0]['Model']
    print(f"Best classification model: {best_model_name}")
    
    # For tree-based models, we can extract feature importance
    if best_model_name in ['Random Forest', 'Gradient Boosting', 'Decision Tree']:
        # Import and get models
        from modeling import get_classification_models
        models = get_classification_models()
        
        # Get the best model
        best_model = models[best_model_name]
        
        # Create full pipeline
        from sklearn.pipeline import Pipeline
        pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', best_model)])
        
        # Fit model
        pipeline.fit(X_train, y_train)
        
        # Get feature names after preprocessing
        feature_names = numeric_cols.copy()
        # For categorical features, get one-hot encoded column names
        for cat_col in categorical_cols:
            unique_values = X_train[cat_col].unique()
            for value in unique_values:
                feature_names.append(f"{cat_col}_{value}")
        
        # Get feature importances
        importances = pipeline.named_steps['model'].feature_importances_
        
        # Get the right number of feature names
        if len(feature_names) > len(importances):
            feature_names = feature_names[:len(importances)]
        
        # Plot feature importance
        plot_feature_importance(feature_names, importances, title=f"{best_model_name} - Feature Importance")
else:
    print("Please run the model evaluation first.")

# %% [markdown]
# ## 8. Save the Best Model
#
# Save the best performing model for later use.

# %%
# Save the best model
if 'pipeline' in locals():
    from modeling import save_model
    
    # Create models directory if it doesn't exist
    import os
    os.makedirs('../models', exist_ok=True)
    
    # Save model
    model_path = f'../models/best_{problem_type}_model.pkl'
    save_model(pipeline, model_path)
    
    print(f"Model saved to {model_path}")
else:
    print("Please run the model evaluation first.")

# %% [markdown]
# ## 9. Next Steps
#
# Here are some suggestions for next steps:
#
# 1. **Feature Engineering**: Create new features or transform existing ones to improve model performance
# 2. **Hyperparameter Tuning**: Fine-tune the best model to improve its performance
# 3. **Model Interpretation**: Use tools like SHAP values to better understand model predictions
# 4. **Cross-Validation**: Perform more robust model evaluation using cross-validation
# 5. **Create a Prediction Pipeline**: Build a reusable pipeline for making predictions on new data
